# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/random_data.csv')

# %%
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0    275975.0  33.0    Male    38.0             23.0            1.0
# 1    397265.0  46.0  Female    51.0              9.0            4.0
# 2    222896.0  18.0  Female    56.0             18.0            0.0
# 3     76485.0  35.0  Female    52.0             28.0            1.0
# 4    399690.0  42.0  Female    45.0              2.0            2.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           20.0             Basic          Annual       853.46
# 1            6.0             Basic       Quarterly       875.05
# 2           26.0             Basic       Quarterly       325.19
# 3            5.0           Premium         Monthly       229.00
# 4           15.0          Standard       Quarterly       851.49
#
#    Last Interaction  Churn
# 0               9.0    0.0
# 1              10.0    0.0
# 2              30.0    1.0
# 3              12.0    1.0
# 4              12.0    0.0

# %%
churn_counts = df['Churn'].value_counts()

plt.figure(figsize=(6, 4))
churn_counts.plot(kind='bar')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn Distribution')
plt.tight_layout()
plt.show()

# %%
bins = list(range(0, 90, 10))
labels = [f"{i}-{i+10}" for i in bins[:-1]]

df['AgeRange'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

age_range_counts = df['AgeRange'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
age_range_counts.plot(kind='bar')
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.title('Age Distribution by Range')
plt.tight_layout()
plt.show()

# %%
gender_counts = df['Gender'].value_counts()

plt.figure(figsize=(6, 4))
gender_counts.plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.tight_layout()
plt.show()

# %%
subscription_counts = df['Subscription Type'].value_counts()

plt.figure(figsize=(6, 4))
subscription_counts.plot(kind='bar')
plt.xlabel('Subscription Type')
plt.ylabel('Count')
plt.title('Subscription Type Distribution')
plt.tight_layout()
plt.show()

# %%
contract_counts = df['Contract Length'].value_counts()

plt.figure(figsize=(6, 4))
contract_counts.plot(kind='bar')
plt.xlabel('Contract Length')
plt.ylabel('Count')
plt.title('Contract Lenght Distribution')
plt.tight_layout()
plt.show()
